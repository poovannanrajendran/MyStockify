# %%
import quandl
quandl.ApiConfig.api_key = "3T5VPjqDYQpVKsar3k_d"

# %%
from stocker import Stocker
myticker = Stocker(ticker='AXISBANK', exchange='NSE')
stock_history = myticker.stock
stock_history.tail()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# AXISBANK Stocker Initialized. Data covers 2007-08-16 00:00:00 to 2019-01-04 00:00:00.
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2816 2018-12-31  630.4  631.95  618.80  619.90  619.90             6030093.0
# 2817 2019-01-01  621.9  630.20  621.90  628.00  627.30            12179223.0
# 2818 2019-01-02  623.0  628.50  617.50  619.45  620.05            12386281.0
# 2819 2019-01-03  621.4  622.00  603.65  609.00  607.95            13228602.0
# 2820 2019-01-04  612.0  624.75  609.50  620.00  619.60             8381367.0
#
#       Turnover (Lacs)         ds  Adj. Close  Adj. Open       y  Daily Change
# 2816         37644.59 2018-12-31      619.90      630.4  619.90        -10.50
# 2817         76094.60 2019-01-01      627.30      621.9  627.30          5.40
# 2818         77205.46 2019-01-02      620.05      623.0  620.05         -2.95
# 2819         80928.34 2019-01-03      607.95      621.4  607.95        -13.45
# 2820         51786.78 2019-01-04      619.60      612.0  619.60          7.60

# %%
myticker.plot_stock(start_date = '2015-01-03', end_date = '2019-01-04', 
                     stats = ['Daily Change', 'Adj. Close'], plot_type='pct')
# Out:
# Maximum Daily Change = 57.95 on 2018-04-27 00:00:00.
# Minimum Daily Change = -38.15 on 2015-03-04 00:00:00.
# Current Daily Change = 7.60 on 2019-01-04 00:00:00.
#
# Maximum Adj. Close = 660.05 on 2018-08-28 00:00:00.
# Minimum Adj. Close = 373.20 on 2016-01-18 00:00:00.
# Current Adj. Close = 619.60 on 2019-01-04 00:00:00.

# %%
myticker.buy_and_hold(start_date='2015-01-01', end_date='2019-01-04', nshares=100)
# Out:
# AXISBANK Total buy and hold profit from 2015-01-01 00:00:00 to 2019-01-04 00:00:00 for 100 shares = $11695.00

# %%
import sys
path_to_stocker = 'C:\\Users\\Poovannan Rajendran\\Data-Analysis\\stocker'
sys.path.insert(0, path_to_stocker)

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
#from pytrends.request import TrendReq
#pytrends = TrendReq(hl='en-US', tz=360, retries=10, backoff_factor=0.5)

# %%
#Stocker.predict_future(days=30)

# %%
#myticker.changepoint_date_analysis(search='myticker')

# %%
myticker.predict_future(days=600)
# Out:
# Predicted Increase:
#
#           Date     estimate    change        upper       lower
# 2   2019-01-06   634.324198  3.690693   657.493024  612.984691
# 3   2019-01-07   638.647049  4.322851   661.114878  616.374775
# 4   2019-01-08   643.446970  4.799922   665.845361  622.580880
# 5   2019-01-09   646.979253  3.532283   669.548320  624.229780
# 6   2019-01-10   648.412357  1.433104   671.711367  626.837479
# ..         ...          ...       ...          ...         ...
# 594 2020-08-20  1031.202934  1.525623  1544.954472  479.152285
# 595 2020-08-21  1033.783456  2.580522  1547.412191  489.067546
# 597 2020-08-23  1037.956060  4.172604  1554.617002  483.659241
# 598 2020-08-24  1037.966579  0.010519  1554.523118  480.637787
# 600 2020-08-26  1038.089183  0.570060  1557.480662  473.617894
#
# [339 rows x 5 columns]
#
# Predicted Decrease:
#
#           Date     estimate    change        upper       lower
# 18  2019-01-22   662.437661 -0.093610   684.488582  639.872426
# 19  2019-01-23   661.233104 -1.204557   683.869501  638.992298
# 20  2019-01-24   660.347765 -0.885339   683.268562  637.160581
# 25  2019-01-29   665.373439 -0.540655   689.170913  643.275302
# 26  2019-01-30   664.277006 -1.096433   686.492104  642.264533
# ..         ...          ...       ...          ...         ...
# 556 2020-07-13   980.718081 -0.037359  1453.138438  491.389505
# 563 2020-07-20   987.654176 -0.096184  1470.102752  489.183000
# 567 2020-07-24   990.988428 -0.365090  1475.117273  479.551181
# 569 2020-07-26   988.632441 -2.355987  1473.884527  484.966656
# 599 2020-08-25  1037.519123 -0.447456  1568.109012  481.071314
#
# [175 rows x 5 columns]

# %%
from yahoo_fin import stock_info as si
si.get_live_price('AXISBANK.NS')
#data = yf.download('mytickerbank.ns','2020-01-01','2020-01-21')
#si.get_live_price("mytickerbank.ns")
# Out:
# 717.5999755859375
